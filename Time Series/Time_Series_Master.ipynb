# %%
from datetime import datetime
now = datetime.now()
now
# Out:
# datetime.datetime(2020, 10, 28, 8, 18, 43, 539095)

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24, 8, 15)
delta
# Out:
# datetime.timedelta(926, 56700)

# %%
from datetime import timedelta
start = datetime(2011, 1, 7)
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
# Data to string
stamp = datetime(2011, 1, 3)
str(stamp)
stamp.strftime('%Y-%m-%d'),stamp.strftime('%U-%W')
# Out:
# ('2011-01-03', '01-01')

# %%
# String to date 
value = '2011-01-03'
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
datestrs = ['7/6/2011', '8/6/2011', '11/10/2020','12/11/2019']
[datetime.strptime(x,'%d/%m/%Y') for x in datestrs]
# Out:
# [datetime.datetime(2011, 6, 7, 0, 0),
#  datetime.datetime(2011, 6, 8, 0, 0),
#  datetime.datetime(2020, 10, 11, 0, 0),
#  datetime.datetime(2019, 11, 12, 0, 0)]

# %%
# using parse we can parse most human readble date formats , by default it gets installed with pandas 
from dateutil.parser import parse
parse('Jan 31, 1997 10:45 PM')  
parse('6/12/2011', dayfirst=True)
# Out:
# datetime.datetime(2011, 12, 6, 0, 0)

# %%
datestrs = ['2011-07-06 12:00:00', '2011-08-06 00:00:00']
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[ns]', freq=None)

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
....: datetime(2011, 1, 7), datetime(2011, 1, 8),
....: datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
dates
# Out:
# [datetime.datetime(2011, 1, 2, 0, 0),
#  datetime.datetime(2011, 1, 5, 0, 0),
#  datetime.datetime(2011, 1, 7, 0, 0),
#  datetime.datetime(2011, 1, 8, 0, 0),
#  datetime.datetime(2011, 1, 10, 0, 0),
#  datetime.datetime(2011, 1, 12, 0, 0)]

# %%
import numpy as np
ts = pd.Series(np.random.randn(6), index=dates)
ts
# Out:
# 2011-01-02   -0.313516
# 2011-01-05   -1.069212
# 2011-01-07    0.479591
# 2011-01-08   -0.646994
# 2011-01-10    1.655008
# 2011-01-12   -0.263684
# dtype: float64

# %%
# long time series can be passed with period 
longer_ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
# indexing with year or month 
longer_ts['2001']
longer_ts['2001-04']

# Slicing with date time
ts[datetime(2011, 1, 7):]
# Out:
# 2011-01-07    0.479591
# 2011-01-08   -0.646994
# 2011-01-10    1.655008
# 2011-01-12   -0.263684
# dtype: float64

# %%
# Time series is ordered , so can do a range query
ts['1/6/2011':'1/11/2011']
# Out:
# 2011-01-07    0.479591
# 2011-01-08   -0.646994
# 2011-01-10    1.655008
# dtype: float64

# %%
# another method to slide is truncate 
ts.truncate(after='1/9/2011')
# Out:
# 2011-01-02   -0.313516
# 2011-01-05   -1.069212
# 2011-01-07    0.479591
# 2011-01-08   -0.646994
# dtype: float64

# %%
dates = pd.date_range('1/1/2000', periods=100, freq='W-WED')
dates
# Out:
# DatetimeIndex(['2000-01-05', '2000-01-12', '2000-01-19', '2000-01-26',
#                '2000-02-02', '2000-02-09', '2000-02-16', '2000-02-23',
#                '2000-03-01', '2000-03-08', '2000-03-15', '2000-03-22',
#                '2000-03-29', '2000-04-05', '2000-04-12', '2000-04-19',
#                '2000-04-26', '2000-05-03', '2000-05-10', '2000-05-17',
#                '2000-05-24', '2000-05-31', '2000-06-07', '2000-06-14',
#                '2000-06-21', '2000-06-28', '2000-07-05', '2000-07-12',
#                '2000-07-19', '2000-07-26', '2000-08-02', '2000-08-09',
#                '2000-08-16', '2000-08-23', '2000-08-30', '2000-09-06',
#                '2000-09-13', '2000-09-20', '2000-09-27', '2000-10-04',
#                '2000-10-11', '2000-10-18', '2000-10-25', '2000-11-01',
#                '2000-11-08', '2000-11-15', '2000-11-22', '2000-11-29',
#                '2000-12-06', '2000-12-13', '2000-12-20', '2000-12-27',
# ...

# %%
long_df = pd.DataFrame(np.random.randn(100, 4),
index=dates,
columns=['Colorado', 'Texas',
'New York', 'Ohio'])
long_df.head(5)
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.085800  0.057540 -0.941309  0.692742
# 2000-01-12  1.524951 -1.027496 -1.202264 -1.410797
# 2000-01-19 -0.775396 -1.211939 -0.100952 -0.907648
# 2000-01-26 -2.568935 -0.203725 -0.096997 -0.958519
# 2000-02-02 -0.936347  0.718862 -1.891506 -1.807008
