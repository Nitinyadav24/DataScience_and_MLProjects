# %%
import pandas as pd
import numpy as np
string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])

# %%
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data[0]=None

# %%
string_data.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
from numpy import nan as NA
data = pd.Series([1, NA, 3.5, NA, 7])

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA],[NA, NA, NA], [NA, 6.5, 3.]])

# %%
data.dropna(how='all',axis=1)
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.randn(7, 3))

# %%
df.iloc[:4, 1] = NA

# %%
df.iloc[:2, 2]=NA

# %%
_ = df.fillna(0, inplace=True)

# %%
df
# Out:
#           0         1         2
# 0 -0.001696  0.000000  0.000000
# 1 -0.266845  0.000000  0.000000
# 2  1.372261  0.000000  0.906372
# 3  1.421536  0.000000  0.550979
# 4  1.760529  0.065115  0.090941
# 5  0.211201  0.454188 -0.444576
# 6 -1.695930  0.267677 -0.006719

# %%
df.iloc[1:4,1:3]=NA

# %%
df[1].fillna(df[1].mean())
# Out:
# 0    0.000000
# 1    0.196745
# 2    0.196745
# 3    0.196745
# 4    0.065115
# 5    0.454188
# 6    0.267677
# Name: 1, dtype: float64

# %%
df.iloc[:,1:3].fillna(df.iloc[:,1:3].mean())
# Out:
#           1         2
# 0  0.000000  0.000000
# 1  0.196745 -0.090088
# 2  0.196745 -0.090088
# 3  0.196745 -0.090088
# 4  0.065115  0.090941
# 5  0.454188 -0.444576
# 6  0.267677 -0.006719

# %%
df
# Out:
#           0         1         2
# 0 -0.001696  0.000000  0.000000
# 1 -0.266845       NaN       NaN
# 2  1.372261       NaN       NaN
# 3  1.421536       NaN       NaN
# 4  1.760529  0.065115  0.090941
# 5  0.211201  0.454188 -0.444576
# 6 -1.695930  0.267677 -0.006719
