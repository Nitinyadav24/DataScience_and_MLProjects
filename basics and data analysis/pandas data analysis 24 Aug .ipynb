# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({'a':(1,2,0,4,5),'b':(2,3,0,5,6)})
df
# Out:
#    a  b
# 0  1  2
# 1  2  3
# 2  0  0
# 3  4  5
# 4  5  6

# %%
(df[['a','b']]==0).sum()
# Out:
# a    1
# b    1
# dtype: int64

# %%
type([1,2,3,4,5,6])
# Out:
# list

# %%
df[['a','b']]=df[['a','b']].replace(0,np.NaN)
df
# Out:
#      a    b
# 0  1.0  2.0
# 1  2.0  3.0
# 2  NaN  NaN
# 3  4.0  5.0
# 4  5.0  6.0

# %%
df.fillna(df.mean(),inplace=True)
df
# Out:
#      a    b
# 0  1.0  2.0
# 1  2.0  3.0
# 2  3.0  4.0
# 3  4.0  5.0
# 4  5.0  6.0

# %%
pip install fancyimpute

# %%
from fancyimpute import KNN

# %%
df=pd.DataFrame(KNN(k=2).fit_transform(df))
# Out:
# Imputing row 1/5 with 0 missing, elapsed time: 0.001
# [KNN] Warning: 2/10 still missing after imputation, replacing with 0

# %%
df
# Out:
#      0    1
# 0  1.0  2.0
# 1  2.0  3.0
# 2  0.0  0.0
# 3  4.0  5.0
# 4  5.0  6.0

# %%
df=pd.read_csv('Indicators.csv')

# %%
df.head(n=7)
# Out:
#   CountryName CountryCode  ...    Year         Value
# 0  Arab World         ARB  ...  1960.0  1.335609e+02
# 1  Arab World         ARB  ...  1960.0  8.779760e+01
# 2  Arab World         ARB  ...  1960.0  6.634579e+00
# 3  Arab World         ARB  ...  1960.0  8.102333e+01
# 4  Arab World         ARB  ...  1960.0  3.000000e+06
# 5  Arab World         ARB  ...  1960.0  5.380000e+08
# 6  Arab World         ARB  ...  1960.0  4.769789e+01
#
# [7 rows x 6 columns]

# %%
list(df)
# Out:
# ['CountryName',
#  'CountryCode',
#  'IndicatorName',
#  'IndicatorCode',
#  'Year',
#  'Value']

# %%
df.dtypes
# Out:
# CountryName       object
# CountryCode       object
# IndicatorName     object
# IndicatorCode     object
# Year             float64
# Value            float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#        CountryName CountryCode  ...          Year         Value
# count        94823       94823  ...  94822.000000  9.482200e+04
# unique         247         247  ...           NaN           NaN
# top          India         IND  ...           NaN           NaN
# freq           983         983  ...           NaN           NaN
# mean           NaN         NaN  ...   1961.405043  3.228002e+11
# std            NaN         NaN  ...      1.039108  8.346724e+12
# min            NaN         NaN  ...   1960.000000 -1.181558e+14
# 25%            NaN         NaN  ...   1961.000000  6.432749e+00
# 50%            NaN         NaN  ...   1961.000000  6.737133e+01
# 75%            NaN         NaN  ...   1962.000000  6.000000e+06
# max            NaN         NaN  ...   1963.000000  5.037593e+14
#
# [11 rows x 6 columns]

# %%
len(df['CountryName'].unique().tolist())
# Out:
# 247

# %%
from collections import Counter

# %%
C=Counter(df['CountryCode'].tolist())
C.most_common(1)
# Out:
# [('IND', 983)]

# %%
c.most_common(2)
# Out:
# [('India', 983), ('Chile', 928)]

# %%
df['CountryCode'].value_counts()
# Out:
# IND    983
# CHL    928
# HND    892
# AUS    886
# BRA    849
#       ...
# WBG     33
# SRB     20
# MAF     12
# KSV     12
# SXM     10
# Name: CountryCode, Length: 247, dtype: int64

# %%
df
# Out:
#        CountryName CountryCode  ...    Year         Value
# 0       Arab World         ARB  ...  1960.0  1.335609e+02
# 1       Arab World         ARB  ...  1960.0  8.779760e+01
# 2       Arab World         ARB  ...  1960.0  6.634579e+00
# 3       Arab World         ARB  ...  1960.0  8.102333e+01
# 4       Arab World         ARB  ...  1960.0  3.000000e+06
# ...            ...         ...  ...     ...           ...
# 94818  Korea, Rep.         KOR  ...  1963.0  6.235566e+00
# 94819  Korea, Rep.         KOR  ...  1963.0  0.000000e+00
# 94820  Korea, Rep.         KOR  ...  1963.0  0.000000e+00
# 94821  Korea, Rep.         KOR  ...  1963.0  0.000000e+00
# 94822  Korea, Rep.         KOR  ...     NaN           NaN
#
# [94823 rows x 6 columns]

# %%
df5=df.head()

# %%
df5
# Out:
#   CountryName CountryCode  ...    Year         Value
# 0  Arab World         ARB  ...  1960.0  1.335609e+02
# 1  Arab World         ARB  ...  1960.0  8.779760e+01
# 2  Arab World         ARB  ...  1960.0  6.634579e+00
# 3  Arab World         ARB  ...  1960.0  8.102333e+01
# 4  Arab World         ARB  ...  1960.0  3.000000e+06
#
# [5 rows x 6 columns]

# %%
df.iloc[:,:2]
# Out:
#        CountryName CountryCode
# 0       Arab World         ARB
# 1       Arab World         ARB
# 2       Arab World         ARB
# 3       Arab World         ARB
# 4       Arab World         ARB
# ...            ...         ...
# 94818  Korea, Rep.         KOR
# 94819  Korea, Rep.         KOR
# 94820  Korea, Rep.         KOR
# 94821  Korea, Rep.         KOR
# 94822  Korea, Rep.         KOR
#
# [94823 rows x 2 columns]

# %%
df.loc[[0,1],['Value']]
# Out:
#         Value
# 0  133.560907
# 1   87.797601

# %%
df[df.isna().values]
# Out:
#        CountryName CountryCode  ... Year Value
# 94822  Korea, Rep.         KOR  ...  NaN   NaN
# 94822  Korea, Rep.         KOR  ...  NaN   NaN
#
# [2 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# IndicatorName    0
# IndicatorCode    0
# Year             1
# Value            1
# dtype: int64

# %%
df5
# Out:
#   CountryName CountryCode  ...    Year         Value
# 0  Arab World         ARB  ...  1960.0  1.335609e+02
# 1  Arab World         ARB  ...  1960.0  8.779760e+01
# 2  Arab World         ARB  ...  1960.0  6.634579e+00
# 3  Arab World         ARB  ...  1960.0  8.102333e+01
# 4  Arab World         ARB  ...  1960.0  3.000000e+06
#
# [5 rows x 6 columns]

# %%
df5.drop(df.columns['Value'],axis=1)
# Out:
#   CountryName CountryCode  ...   IndicatorCode    Year
# 0  Arab World         ARB  ...     SP.ADO.TFRT  1960.0
# 1  Arab World         ARB  ...     SP.POP.DPND  1960.0
# 2  Arab World         ARB  ...  SP.POP.DPND.OL  1960.0
# 3  Arab World         ARB  ...  SP.POP.DPND.YG  1960.0
# 4  Arab World         ARB  ...  MS.MIL.XPRT.KD  1960.0
#
# [5 rows x 5 columns]

# %%
df.rename(columns={'Value':'Count'})
# Out:
#        CountryName CountryCode  ...    Year         Count
# 0       Arab World         ARB  ...  1960.0  1.335609e+02
# 1       Arab World         ARB  ...  1960.0  8.779760e+01
# 2       Arab World         ARB  ...  1960.0  6.634579e+00
# 3       Arab World         ARB  ...  1960.0  8.102333e+01
# 4       Arab World         ARB  ...  1960.0  3.000000e+06
# ...            ...         ...  ...     ...           ...
# 94818  Korea, Rep.         KOR  ...  1963.0  6.235566e+00
# 94819  Korea, Rep.         KOR  ...  1963.0  0.000000e+00
# 94820  Korea, Rep.         KOR  ...  1963.0  0.000000e+00
# 94821  Korea, Rep.         KOR  ...  1963.0  0.000000e+00
# 94822  Korea, Rep.         KOR  ...     NaN           NaN
#
# [94823 rows x 6 columns]

# %%
name=[['a','2-2-15','$20'],['b','3-3-15','$30'],['c','5-5-15','$36']]
df=pd.DataFrame(name,columns=['Name','date','Money'])

# %%
df['Money']=df['Money'].map(lambda X : X.replace('$',' '))
df['Money']=df['Money'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-9743613eaa3d> in <module>()
# ----> 1 df['Money']=df['Money'].map(lambda X : X.replace('$',' '))
#       2 df['Money']=df['Money'].astype(float)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
df.describe()
# Out:
#              Age      Money
# count   3.000000   3.000000
# mean   14.666667  28.666667
# std     2.516611   8.082904
# min    12.000000  20.000000
# 25%    13.500000  25.000000
# 50%    15.000000  30.000000
# 75%    16.000000  33.000000
# max    17.000000  36.000000

# %%
df
# Out:
#            Name Money
# date
# 2015-02-02    a   $20
# 2015-03-03    b   $30
# 2015-05-05    c   $36

# %%
df['date']=pd.to_datetime(df['date'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-bb7b3a3a3289> in <module>()
# ...

# %%
am=df.set_index('date',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-3cbeba65fd5c> in <module>()
# ----> 1 am=df.set_index('date',inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
df['2015']
# Out:
#            Name Money
# date
# 2015-02-02    a   $20
# 2015-03-03    b   $30
# 2015-05-05    c   $36

# %%
df
# Out:
#            Name Money
# date
# 2015-02-02    a   $20
# 2015-03-03    b   $30
# 2015-05-05    c   $36

# %%
df=df.reset_index()

# %%
date0=df['date'].min()
df['diff']=df['date'].apply(lambda X: (X-date0).days)
df
# Out:
#         date Name Money  diff
# 0 2015-02-02    a   $20     0
# 1 2015-03-03    b   $30    29
# 2 2015-05-05    c   $36    92
