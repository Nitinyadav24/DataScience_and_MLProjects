# %%
import numpy as np
import pandas as pd

# %%
df={'Age':['2 years' , '< 1 Year','10+ years'],'Inc':[20,30,40]}
df1=pd.DataFrame(df)

# %%
df1
# Out:
#          Age  Inc
# 0    2 years   20
# 1   < 1 Year   30
# 2  10+ years   40

# %%
df1.columns.values
# Out:
# array(['Age', 'Inc'], dtype=object)

# %%
df1['Age'].unique
# Out:
# <bound method Series.unique of 0      2 years
# 1     < 1 Year
# 2    10+ years
# Name: Age, dtype: object>

# %%
df1['Age']=df1['Age'].str.replace('\+ years','')
df1['Age']=df1['Age'].str.replace(' years','')
df1['Age']=df1['Age'].str.replace('< 1 Year',str(0))

# %%
df1
# Out:
#   Age  Inc
# 0   2   20
# 1   0   30
# 2  10   40

# %%
print(type((df1['Age'])[0])) # to check the first element of series using type command 
df1['Age']=pd.to_numeric(df1['Age'])
# Out:
# <class 'numpy.int64'>

# %%
round(pd.to_numeric((pd.to_datetime('2017-12-1')-pd.to_datetime('2013-11-1'))/np.timedelta64(1,'M')))
# Out:
# 49
