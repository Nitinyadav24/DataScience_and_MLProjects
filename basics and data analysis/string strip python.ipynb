# %%
word='Yadav,Mr .Nitin'

# %%
word
# Out:
# 'Yadav,Mr.Nitin'

# %%
type(word)
# Out:
# str

# %%
word.split(',')
# Out:
# ['Yadav', 'Mr .Nitin']

# %%
word.split(',')[1].split('.')[0].strip()
# Out:
# 'Mr'
