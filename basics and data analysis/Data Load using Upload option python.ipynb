# %%
from google.colab import files
upload_file=files.upload()
# Out:
#      <input type="file" id="files-5340924e-2bf1-4e01-888e-1f1d5e590575" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5340924e-2bf1-4e01-888e-1f1d5e590575">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMDB-Data.csv to IMDB-Data.csv

# %%
# !ls
# Out:
# IMDB-Data.csv  sample_data

# %%
import pandas as pd

# %%
df=pd.read_csv('IMDB-Data.csv')

# %%
df.head()
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
#
# [5 rows x 12 columns]
