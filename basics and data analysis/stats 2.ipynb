# %%
import numpy as np
import pandas as pd
import math
from scipy.stats import stats
from scipy.stats import ttest_1samp

# %%
from google.colab import files
upload_file=files.upload()
# Out:
#      <input type="file" id="files-1981c7e6-cfb6-4e58-8187-5817c04a088c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1981c7e6-cfb6-4e58-8187-5817c04a088c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving InternetMobileTime+.csv to InternetMobileTime+.csv

# %%
df=pd.read_csv('InternetMobileTime+.csv')
df.head()
# Out:
#    Minutes
# 0       72
# 1      144
# 2       48
# 3       72
# 4       36

# %% [markdown]
# H0 : Mean Time = 144
# H1 : Mean Time is not equal to 144

# %%
t_statistic, p_val=ttest_1samp(df,144)
print('one sample t test \nt statistic {0} p value {1}'.format(t_statistic,p_val))
# Out:
# one sample t test
# t statistic [1.22467437] p value [0.23055327]

# %% [markdown]
# ## 2 Sample T test

# %%
from scipy.stats import ttest_ind

# %%
from google.colab import files
upload_file=files.upload()
# Out:
#      <input type="file" id="files-a86d64dc-aaa2-4dec-a12c-494f8298ea32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a86d64dc-aaa2-4dec-a12c-494f8298ea32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df=pd.read_csv('Luggage.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-b18ebcbd3852> in <module>()
# ----> 1 df=pd.read_csv('Luggage.csv')
#       2 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %% [markdown]
# Step 1: Define Hypothesis
#
# H0 : Wing A = Wing B
# H1 : Wing A not equal to wing B
# Alpha = 0.05

# %%
t_statistic, p_value=ttest_ind(df['WingA'],df['WingB'])
print('tstats' ,t_statistic)
print('p val', p_value)

# %%
from google.colab import files
upload_file=files.upload()

# %%
df=pd.read_csv('Concrete.csv')
df.head()

# %% [markdown]
# state Hypothesis
# H0: MS(2) >= MS(7)
# H1: MS(2) < MS(7)
# Alpha - 0.01

# %%
t_statistic,p_value=stats.ttest_rel(df['Two Days'],df['Seven Days'])
print('t stat %1.3f' % t_statistic)
print('p value %1.2f', p_value/2)

# %%
from scipy.stats import chi2_contingency
import pandas as pd

# %%
df=pd.DataFrame({'Promoted':[15,16],'Not Promoted':[9,15]}, index=['Company A', 'Company B'])
df
# Out:
#            Promoted  Not Promoted
# Company A        15             9
# Company B        16            15

# %%
chi2,pval,dof,exp_freq=chi2_contingency(df,correction=False)
pval
# Out:
# 0.41943105261448455
