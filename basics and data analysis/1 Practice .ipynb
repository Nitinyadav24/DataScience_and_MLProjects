# %%
list=[12,3,4,5]
list.index(12)
# Out:
# 0

# %%
a=1
for i in range(1,6):
  a=a*i
  print(a)
# Out:
# 1
# 2
# 6
# 24
# 120

# %%
i='20'
if i>20:
  print(1)
else:
  print(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3ceac90089f8> in <module>()
#       1 i='20'
# ----> 2 if i>20:
#       3   print(1)
#       4 else:
#       5   print(2)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
another_fun=lambda x,y,z: (x**y)+(y/z)+(x-y)+(z-y)-(y*x)
print(another_fun(5,7,9))
# Out:
# 78090.77777777778
