# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set(color_codes=True)
# %matplotlib inline 
import statistics

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.tail(10)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 758            1      106  ...   26        0
# 759            6      190  ...   66        1
# 760            2       88  ...   22        0
# 761            9      170  ...   43        1
# 762            9       89  ...   33        0
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [10 rows x 9 columns]

# %%
df.shape
# Out:
# (768, 9)

# %%
df.size
# Out:
# 6912

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
sns.distplot(df['BloodPressure'])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.loc[df['Glucose']==df['Glucose'].max(),'BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %%
df.Glucose.mean()
# Out:
# 120.89453125

# %%
df.loc[df['Glucose']>df['Glucose'].mean()]['Glucose'].count()
# Out:
# 349

# %%
df['BloodPressure'].median()
# Out:
# 72.0

# %%
statistics.mode(df['Insulin'])
# Out:
# 0

# %%
statistics.mode(df['BMI'])
# Out:
# 32.0

# %%
df.loc[(df['BMI']<statistics.mode(df['BMI'])) & (df['BloodPressure']==df['BloodPressure'].median())].count()
# Out:
# Pregnancies                 22
# Glucose                     22
# BloodPressure               22
# SkinThickness               22
# Insulin                     22
# BMI                         22
# DiabetesPedigreeFunction    22
# Age                         22
# Outcome                     22
# dtype: int64

# %%
plt.hist(df['Age'])
plt.show()

# %%
sns.pairplot(df.loc[:,['Glucose','SkinThickness','DiabetesPedigreeFunction']])

# %%
sns.jointplot(x='Glucose', y="Insulin", data=df)

# %%
sns.scatterplot(df['Glucose'],df['Insulin'])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.groupby('Outcome').size()
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
df=pd.read_csv('/content/uberdrive.csv', error_bad_lines=True)

# %%
df.head()
# Out:
#         START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 0  01-01-2016 21:11  01-01-2016 21:17  ...    5.1   Meal/Entertain
# 1  01-02-2016 01:25  01-02-2016 01:37  ...    5.0              NaN
# 2  01-02-2016 20:25  01-02-2016 20:38  ...    4.8  Errand/Supplies
# 3  01-05-2016 17:31  01-05-2016 17:45  ...    4.7          Meeting
# 4  01-06-2016 14:42  01-06-2016 15:49  ...   63.7   Customer Visit
#
# [5 rows x 7 columns]

# %%
df.tail(10)
# Out:
#            START_DATE*         END_DATE*  ...   MILES*         PURPOSE*
# 1146  12/30/2016 11:31  12/30/2016 11:56  ...      2.9  Errand/Supplies
# 1147  12/30/2016 15:41  12/30/2016 16:03  ...      4.6  Errand/Supplies
# 1148  12/30/2016 16:45  12/30/2016 17:08  ...      4.6          Meeting
# 1149  12/30/2016 23:06  12/30/2016 23:10  ...      0.8   Customer Visit
# 1150   12/31/2016 1:07   12/31/2016 1:14  ...      0.7          Meeting
# 1151  12/31/2016 13:24  12/31/2016 13:42  ...      3.9   Temporary Site
# 1152  12/31/2016 15:03  12/31/2016 15:38  ...     16.2          Meeting
# 1153  12/31/2016 21:32  12/31/2016 21:50  ...      6.4   Temporary Site
# 1154  12/31/2016 22:08  12/31/2016 23:51  ...     48.2   Temporary Site
# 1155            Totals               NaN  ...  12204.7              NaN
#
# [10 rows x 7 columns]

# %%
df.head(10)
# Out:
#         START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 0  01-01-2016 21:11  01-01-2016 21:17  ...    5.1   Meal/Entertain
# 1  01-02-2016 01:25  01-02-2016 01:37  ...    5.0              NaN
# 2  01-02-2016 20:25  01-02-2016 20:38  ...    4.8  Errand/Supplies
# 3  01-05-2016 17:31  01-05-2016 17:45  ...    4.7          Meeting
# 4  01-06-2016 14:42  01-06-2016 15:49  ...   63.7   Customer Visit
# 5  01-06-2016 17:15  01-06-2016 17:19  ...    4.3   Meal/Entertain
# 6  01-06-2016 17:30  01-06-2016 17:35  ...    7.1          Meeting
# 7  01-07-2016 13:27  01-07-2016 13:33  ...    0.8          Meeting
# 8  01-10-2016 08:05  01-10-2016 08:25  ...    8.3          Meeting
# 9  01-10-2016 12:17  01-10-2016 12:44  ...   16.5   Customer Visit
#
# [10 rows x 7 columns]

# %%
df.shape
# Out:
# (1156, 7)

# %%
print('no of rows:', df.shape[0])
# Out:
# no of rows: 1156

# %%
df.size
# Out:
# 8092

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.dropna()
# Out:
#            START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 0     01-01-2016 21:11  01-01-2016 21:17  ...    5.1   Meal/Entertain
# 2     01-02-2016 20:25  01-02-2016 20:38  ...    4.8  Errand/Supplies
# 3     01-05-2016 17:31  01-05-2016 17:45  ...    4.7          Meeting
# 4     01-06-2016 14:42  01-06-2016 15:49  ...   63.7   Customer Visit
# 5     01-06-2016 17:15  01-06-2016 17:19  ...    4.3   Meal/Entertain
# ...                ...               ...  ...    ...              ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  ...    0.7          Meeting
# 1151  12/31/2016 13:24  12/31/2016 13:42  ...    3.9   Temporary Site
# 1152  12/31/2016 15:03  12/31/2016 15:38  ...   16.2          Meeting
# 1153  12/31/2016 21:32  12/31/2016 21:50  ...    6.4   Temporary Site
# 1154  12/31/2016 22:08  12/31/2016 23:51  ...   48.2   Temporary Site
#
# [653 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
df.isna().values.sum()
# Out:
# 507

# %%
df.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
df=df.dropna(axis=0,how='any')

# %%
df.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %%
df.shape
# Out:
# (653, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %%
df.head()
# Out:
#         START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 0  01-01-2016 21:11  01-01-2016 21:17  ...    5.1   Meal/Entertain
# 2  01-02-2016 20:25  01-02-2016 20:38  ...    4.8  Errand/Supplies
# 3  01-05-2016 17:31  01-05-2016 17:45  ...    4.7          Meeting
# 4  01-06-2016 14:42  01-06-2016 15:49  ...   63.7   Customer Visit
# 5  01-06-2016 17:15  01-06-2016 17:19  ...    4.3   Meal/Entertain
#
# [5 rows x 7 columns]

# %%
df['START*'].unique().shape
# Out:
# (131,)

# %%
df['START*'].nunique()
# Out:
# 131

# %%
df['STOP*'].unique().shape
# Out:
# (137,)

# %%
df.loc[df['START*']=='San Francisco']
# Out:
#           START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 362  05-09-2016 14:39  05-09-2016 15:06  ...   20.5  Between Offices
# 440   6/14/2016 16:09   6/14/2016 16:39  ...   11.6          Meeting
# 917  11-07-2016 19:17  11-07-2016 19:57  ...   13.2  Between Offices
# 919  11-08-2016 12:16  11-08-2016 12:49  ...   11.3          Meeting
# 927  11-09-2016 18:40  11-09-2016 19:17  ...   12.7   Customer Visit
# 933  11-10-2016 15:17  11-10-2016 15:22  ...    9.9   Temporary Site
# 966  11/15/2016 20:44  11/15/2016 21:00  ...   11.8   Temporary Site
#
# [7 rows x 7 columns]

# %%
import statistics

# %%
statistics.mode(df['START*'])
# Out:
# 'Cary'

# %%
df['START*'].value_counts()
# Out:
# Cary                 161
# Unknown Location      55
# Morrisville           54
# Whitebridge           36
# Durham                30
#                     ...
# Sugar Land             1
# Flatiron District      1
# Summerwinds            1
# Metairie               1
# Nugegoda               1
# Name: START*, Length: 131, dtype: int64

# %%
df['STOP*'].value_counts()
# Out:
# Cary                155
# Morrisville          60
# Unknown Location     56
# Whitebridge          37
# Durham               30
#                    ...
# Summerwinds           1
# Metairie              1
# Coxville              1
# Hell's Kitchen        1
# Nugegoda              1
# Name: STOP*, Length: 137, dtype: int64

# %%
# df.loc[(df['START*']==statistics.mode(df['START*'])) & (df['STOP*']==statistics.mode(df['STOP*']))].count()

df.groupby(['START*','STOP*']).size().sort_values(ascending=False).head(2)
# Out:
# START*       STOP*
# Cary         Morrisville    52
# Morrisville  Cary           51
# dtype: int64

# %%
df['PURPOSE*'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Commute              1
# Charity ($)          1
# Name: PURPOSE*, dtype: int64

# %%
np.array(df['PURPOSE*'].unique())
# Out:
# array(['Meal/Entertain', 'Errand/Supplies', 'Meeting', 'Customer Visit',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %%
sns.barplot(x='PURPOSE*', y='MILES*', data=df, estimator=np.sum, ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby('PURPOSE*')['MILES*'].sum().sort_values(ascending=False)
# Out:
# PURPOSE*
# Meeting            2851.3
# Customer Visit     2089.5
# Meal/Entertain      911.7
# Temporary Site      523.7
# Errand/Supplies     508.0
# Between Offices     197.0
# Commute             180.2
# Moving               18.2
# Airport/Travel       16.5
# Charity ($)          15.1
# Name: MILES*, dtype: float64

# %%
df.head()
# Out:
#         START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 0  01-01-2016 21:11  01-01-2016 21:17  ...    5.1   Meal/Entertain
# 2  01-02-2016 20:25  01-02-2016 20:38  ...    4.8  Errand/Supplies
# 3  01-05-2016 17:31  01-05-2016 17:45  ...    4.7          Meeting
# 4  01-06-2016 14:42  01-06-2016 15:49  ...   63.7   Customer Visit
# 5  01-06-2016 17:15  01-06-2016 17:19  ...    4.3   Meal/Entertain
#
# [5 rows x 7 columns]

# %%
sns.countplot(df['CATEGORY*'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.loc[df['CATEGORY*']=='Business']['CATEGORY*'].value_counts()/df['CATEGORY*'].value_counts().sum()
# Out:
# Business    0.990812
# Name: CATEGORY*, dtype: float64

# %%
df.groupby('CATEGORY*').sum()/df['MILES*'].sum()
# Out:
#              MILES*
# CATEGORY*
# Business   0.970798
# Personal   0.029202
