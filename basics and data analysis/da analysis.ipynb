# %%
from sklearn import datasets

# %%
df=datasets.load_digits()

# %%
print(df.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
df.data[0].shape
# Out:
# (64,)

# %%
df.target[0]
# Out:
# 0

# %%
df.target[-10:]
# Out:
# array([5, 4, 8, 8, 4, 9, 0, 8, 9, 8])

# %%
df.target.shape
# Out:
# (1797,)

# %%
df.data.shape
# Out:
# (1797, 64)

# %%
from sklearn import svm

# %%
clf=svm.SVC(gamma=0.001,C=100)

# %%
clf.fit(df.data[:-1],df.target[:-1])
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf.predict(df.data[-1:])
# Out:
# array([8])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(2,2))
plt.imshow(df.images[-1],interpolation='nearest', cmap=plt.cm.binary)

# %%
import pandas as pd

# %%
from ipywidgets import FileUpload
upload = FileUpload()
upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
# !jupyter --paths
# Out:
# config:
#     /home/jovyan/.jupyter
#     /srv/conda/envs/notebook/etc/jupyter
#     /usr/local/etc/jupyter
#     /etc/jupyter
# data:
#     /home/jovyan/.local/share/jupyter
#     /srv/conda/envs/notebook/share/jupyter
#     /usr/local/share/jupyter
#     /usr/share/jupyter
# runtime:
#     /home/jovyan/.local/share/jupyter/runtime

# %%
import os
os.getcwd()
# Out:
# '/home/jovyan/demo'

# %%
df=pd.read_csv('./data/store.csv')

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  MONTH_ID  \
# 0               30      95.70                2  2871.00  Shipped         2
# 1               34      81.35                5  2765.90  Shipped         5
# 2               41      94.74                2  3884.34  Shipped         7
# 3               45      83.26                6  3746.70  Shipped         8
# 4               49     100.00               14  5205.27  Shipped        10
#
#    YEAR_ID  PRODUCTLINE              CUSTOMERNAME           CITY COUNTRY  \
# 0     2003  Motorcycles         Land of Toys Inc.            NYC     USA
# 1     2003  Motorcycles        Reims Collectables          Reims  France
# 2     2003  Motorcycles           Lyon Souveniers          Paris  France
# 3     2003  Motorcycles         Toys4GrownUps.com       Pasadena     USA
# 4     2003  Motorcycles  Corporate Gift Ideas Co.  San Francisco     USA
#
#   TERRITORY DEALSIZE
# 0       NaN    Small
# 1      EMEA    Small
# ...

# %%
gp_c=df.groupby('COUNTRY')

# %%
len(gp_c.get_group('USA'))
# Out:
# 1004

# %% [markdown]
# To give total no of records

# %%
gp_c.size()
# Out:
# COUNTRY
# Australia       185
# Austria          55
# Belgium          33
# Canada           70
# Denmark          63
# Finland          92
# France          314
# Germany          62
# Ireland          16
# Italy           113
# Japan            52
# Norway           85
# Philippines      26
# Singapore        79
# Spain           342
# Sweden           57
# Switzerland      31
# UK              144
# USA            1004
# dtype: int64

# %%
gp_c.first()
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES    STATUS  \
# COUNTRY
# Australia                 37     100.00                1   3965.66   Shipped
# Austria                   41     100.00                9   7737.93   Shipped
# Belgium                   30     100.00                4   3508.80   Shipped
# Canada                    47     100.00                6   9064.89   Shipped
# Denmark                   50     100.00                2   7208.00   Shipped
# Finland                   23     100.00                9   2597.39   Shipped
# France                    34      81.35                5   2765.90   Shipped
# Germany                   21     100.00                3   3840.90   Shipped
# Ireland                   32     100.00                2   7181.44   Shipped
# Italy                     34     100.00                2   8014.82   Shipped
# Japan                     32     100.00                6   7680.64   Shipped
# ...

# %%
gp_c.last()
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES     STATUS  \
# COUNTRY
# Australia                 42      57.61                3  2419.62   Disputed
# Austria                   28      48.17                6  1348.76    Shipped
# Belgium                   37      45.86               10  1696.82    Shipped
# Canada                    33      51.32               12  1693.56    Shipped
# Denmark                   37      86.74                4  3209.38   Resolved
# Finland                   29     100.00                1  3978.51    Shipped
# France                    34      62.24                1  2116.16    Shipped
# Germany                   21      45.19               10   948.99    Shipped
# Ireland                   35     100.00                3  3986.50    Shipped
# Italy                     32      60.06                1  1921.92    Shipped
# Japan                     27      76.31                6  2060.37    Shipped
# ...

# %%
gp_c.get_group('USA').sum()['SALES']
# Out:
# 3627982.83

# %%
gp_c.sum()['SALES']
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
gp_c.mean()['SALES']
# Out:
# COUNTRY
# Australia      3408.773514
# Austria        3673.864182
# Belgium        3285.230909
# Canada         3201.122286
# Denmark        3899.002381
# Finland        3582.412065
# France         3537.950701
# Germany        3556.001452
# Ireland        3609.776875
# Italy          3315.701858
# Japan          3618.611731
# Norway         3617.220000
# Philippines    3615.989615
# Singapore      3651.752025
# Spain          3554.640117
# Sweden         3684.459825
# Switzerland    3797.211613
# UK             3325.558750
# USA            3613.528715
# Name: SALES, dtype: float64

# %%
gp_c.max()['SALES']
# Out:
# COUNTRY
# Australia       9774.03
# Austria         9240.00
# Belgium         6804.63
# Canada          9064.89
# Denmark        10468.90
# Finland        10606.20
# France         11739.70
# Germany         8940.96
# Ireland         8258.00
# Italy           9160.36
# Japan          10758.00
# Norway          8844.12
# Philippines     7483.98
# Singapore      10993.50
# Spain          12001.00
# Sweden          7209.11
# Switzerland     6761.60
# UK             11886.60
# USA            14082.80
# Name: SALES, dtype: float64

# %%
gp_c.agg('sum')
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER       SALES  \
# COUNTRY
# Australia               6246   15449.14             1181   630623.10
# Austria                 1974    4759.16              320   202062.53
# Belgium                 1074    2887.31              164   108412.62
# Canada                  2293    5957.05              415   224078.56
# Denmark                 2197    5503.89              399   245637.15
# Finland                 3192    7722.15              587   329581.91
# France                 11090   25920.87             2028  1110916.52
# Germany                 2148    5184.30              388   220472.09
# Ireland                  490    1377.98               73    57756.43
# Italy                   3773    9329.40              890   374674.31
# Japan                   1842    4290.26              362   188167.81
# Norway                  2842    7318.18              559   307463.70
# ...

# %%
gp_c.agg({'QUANTITYORDERED':'mean','PRICEEACH':'mean','SALES':'sum'})
# Out:
#              QUANTITYORDERED  PRICEEACH       SALES
# COUNTRY
# Australia          33.762162  83.508865   630623.10
# Austria            35.890909  86.530182   202062.53
# Belgium            32.545455  87.494242   108412.62
# Canada             32.757143  85.100714   224078.56
# Denmark            34.873016  87.363333   245637.15
# Finland            34.695652  83.936413   329581.91
# France             35.318471  82.550541  1110916.52
# Germany            34.645161  83.617742   220472.09
# Ireland            30.625000  86.123750    57756.43
# Italy              33.389381  82.561062   374674.31
# Japan              35.423077  82.505000   188167.81
# Norway             33.435294  86.096235   307463.70
# Philippines        36.961538  82.499615    94015.73
# Singapore          34.936709  83.315190   288488.41
# Spain              36.342105  81.995731  1215686.92
# Sweden             35.192982  86.728246   210014.21
# Switzerland        34.774194  87.519032   117713.56
# ...

# %%
gp_c.agg(['sum','mean'])[['QUANTITYORDERED','PRICEEACH','SALES']]
# Out:
#             QUANTITYORDERED            PRICEEACH                  SALES  \
#                         sum       mean       sum       mean         sum
# COUNTRY
# Australia              6246  33.762162  15449.14  83.508865   630623.10
# Austria                1974  35.890909   4759.16  86.530182   202062.53
# Belgium                1074  32.545455   2887.31  87.494242   108412.62
# Canada                 2293  32.757143   5957.05  85.100714   224078.56
# Denmark                2197  34.873016   5503.89  87.363333   245637.15
# Finland                3192  34.695652   7722.15  83.936413   329581.91
# France                11090  35.318471  25920.87  82.550541  1110916.52
# Germany                2148  34.645161   5184.30  83.617742   220472.09
# Ireland                 490  30.625000   1377.98  86.123750    57756.43
# Italy                  3773  33.389381   9329.40  82.561062   374674.31
# Japan                  1842  35.423077   4290.26  82.505000   188167.81
# ...

# %%
[num**2 for num in range(0,10) if num%2==0]
# Out:
# [0, 4, 16, 36, 64]

# %%
dic={'a':1,'b':2}
{key:value**2 for key,value in dic.items()}
# Out:
# {'a': 1, 'b': 4}

# %%
{num:num**2 for num in [1,2,4]}
# Out:
# {1: 1, 2: 4, 4: 16}
