# %%
import pandas as pd
import numpy as np

# %%
np.array(['2020-01-01','2020-02-01'], dtype='datetime64[h]')
# Out:
# array(['2020-01-01T00', '2020-02-01T00'], dtype='datetime64[h]')

# %%
np.arange('1968', '1980', dtype='datetime64[Y]')
# Out:
# array(['1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979'], dtype='datetime64[Y]')

# %%
pd.date_range('2020-01-01',periods=7 , freq='M')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('Jan 01, 2018',periods=7 , freq='D')
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.to_datetime(['02/01/2020','01/08/2020'],format='%m/%d/%Y')
# Out:
# DatetimeIndex(['2020-02-01', '2020-01-08'], dtype='datetime64[ns]', freq=None)
