# %%
import nltk
nltk.download('gutenberg')
nltk.download('genesis')
nltk.download('inaugural')
nltk.download('nps_chat')
nltk.download('webtext')
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package genesis to /root/nltk_data...
# [nltk_data]   Unzipping corpora/genesis.zip.
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Unzipping corpora/inaugural.zip.
# [nltk_data] Downloading package nps_chat to /root/nltk_data...
# [nltk_data]   Unzipping corpora/nps_chat.zip.
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Unzipping corpora/webtext.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# True

# %%
>>> from nltk.book import *
>>> type(text1)
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# nltk.text.Text

# %%
n_words = len(text1)
n_words
# Out:
# 260819

# %%
	
>>> V = set(text6)
>>> long_words = [w for w in V if len(w) > 12]
>>> sorted(long_words)
# Out:
# ['Camaaaaaargue',
#  'Oooohoohohooo',
#  'Unfortunately',
#  'automatically',
#  'indefatigable',
#  'understanding']

# %%
l_char = [word for word in text6 if word.isnumeric()]
len(nltk.FreqDist(l_char))
# Out:
# 24

# %%
>>> n_unique_words = len(set(text1))
>>> n_unique_words
# Out:
# 19317

# %%
>>> text1_lcw = [ word.lower() for word in set(text1) ]
>>> n_unique_words_lc = len(set(text1_lcw))
>>> n_unique_words_lc
# Out:
# 17231

# %%
>>> text6_lcw = [ word for word in set(text6) ]
>>> n_unique_words_lc = len(set(text6_lcw))
>>> n_unique_words_lc
# Out:
# 2166

# %%
# word coverage 
>>> word_coverage1 = n_words / n_unique_words
>>> word_coverage1
# Out:
# 13.502044830977896

# %%
>>> word_coverage2 = n_words / n_unique_words_lc
>>> word_coverage2
# Out:
# 140.6032345013477

# %%
# Filter words 
>>> big_words = [word for word in set(text1) if len(word) > 17 ]
big_words
# Out:
# ['characteristically', 'uninterpenetratingly']

# %%
# Filter words having prefix 
>>> sun_words = [word for word in set(text6) if word.endswith('ship') ]
>>> sun_words
# Out:
# ['dictatorship']

# %%
# Freq dist
>>> text1_freq = nltk.FreqDist(text6)
text1_freq['ARTHUR']
# Out:
# 225

# %%
# Frequent words using most common
>>> top3_text1 = text1_freq.most_common(3)
>>> top3_text1
# Out:
# [(',', 18713), ('the', 13721), ('.', 6862)]

# %%
# Freq Dist for large uncommon words
>>> large_uncommon_words = [word for word in text1 if word.isalpha() and len(word) > 7 ]
>>> text1_uncommon_freq = nltk.FreqDist(large_uncommon_words)
>>> text1_uncommon_freq.most_common(3)
# Out:
# [('Queequeg', 252), ('Starbuck', 196), ('something', 119)]
