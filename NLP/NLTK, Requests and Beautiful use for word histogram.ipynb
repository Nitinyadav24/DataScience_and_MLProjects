# %%
url = 'https://www.gutenberg.org/files/376/376-h/376-h.htm'

# %%
import requests

# %%
r=requests.get(url)

# %%
type(r)
html=r.text
# print(html)

# %%
from bs4 import BeautifulSoup
# Out:
# type

# %%
soup=BeautifulSoup(html,"html5lib")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title.string
# Out:
# 'A Journal of the Plague Year, by Daniel Defoe'

# %%
soup.findAll('a')[:8]
# Out:
# [<a href="#linknote-1" id="linknoteref-1" name="linknoteref-1"><sup>[1]</sup></a>,
#  <a id="linknote-1" name="linknote-1"></a>,
#  <a href="#linknoteref-1">[1]</a>,
#  <a href="#linknote-2" id="linknoteref-2" name="linknoteref-2"><sup>[2]</sup></a>,
#  <a id="linknote-2" name="linknote-2"></a>,
#  <a href="#linknoteref-2">[2]</a>,
#  <a href="#linknote-3" id="linknoteref-3" name="linknoteref-3"><sup>[3]</sup></a>,
#  <a id="linknote-3" name="linknote-3"></a>]

# %%
text=soup.get_text()
#print(text)

# %%
import re
sentence = 'nitin nightmare46 nancy not night day time no2'
ps='\w+'
re.findall(ps,sentence)
# Out:
# ['nitin', 'nightmare46', 'nancy', 'not', 'night', 'day', 'time', 'no2']

# %%
tokens=re.findall('\w+', text)
tokens[:9]
# Out:
# ['A', 'Journal', 'of', 'the', 'Plague', 'Year', 'by', 'Daniel', 'Defoe']

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer('\w+')
tokens=tokenizer.tokenize(text)
tokens[:9]
# Out:
# ['A', 'Journal', 'of', 'the', 'Plague', 'Year', 'by', 'Daniel', 'Defoe']

# %%
words=[]
# Loop thru
for word in tokens:
    words.append(word.lower())
words[:9]
# Out:
# ['a', 'journal', 'of', 'the', 'plague', 'year', 'by', 'daniel', 'defoe']

# %%
import nltk
nltk.download('stopwords')
sw=nltk.corpus.stopwords.words('english')
sw[:5]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we']

# %%
words_ns=[]
for word in words:
    if word not in sw:
        words_ns.append(word)
words_ns[:5]
# Out:
# ['journal', 'plague', 'year', 'daniel', 'defoe']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
freqdist=nltk.FreqDist(words_ns)
freqdist.plot(25)
